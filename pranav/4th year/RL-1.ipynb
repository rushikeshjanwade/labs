# %%
import gym 
import numpy as np 
import tensorflow as tf

#Create and initialize a TensorFlow constant tensor
tensor = tf.constant ([[1, 2], [3, 4]])

#Print the tensor 
print("Tensor:") 
print(tensor)

#Create a TensorFlow variable and initialize it with zeros 
variable = tf.Variable(tf.zeros([2,2]))

#Print the variable 
print("\nvariable:") 
print(variable)

#Update the variable 
variable.assign_add(tf.ones([2,2]))

#Print the updated variable 
print("\nUpdated variable:") 
print(variable)

#Create an environment from OpenAI Gym 
env = gym.make('CartPole-v1')

#Initialize the environment 
state = env.reset()
# Out:
# WARNING:tensorflow:From c:\Users\hp\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Tensor:
# tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)
#
# variable:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[0., 0.],
#        [0., 0.]], dtype=float32)>
#
# Updated variable:
# <tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>

# %%
# Initialize the environment 
state = env.reset()

# Run the environment for 100 steps
for _ in range(100):
    # Render the environment
    env.render()

    # Take a random action 
    action = env.action_space.sample()

    # Perform the action in the environment
    result = env.step(action)
    print("Step Result:", result)

    # Unpack the returned values
    next_state, reward, done, info,_= result

    # If episode is finished, reset the environment
    if done:
        state = env.reset()

# Close the environment
env.close()
# Out:
# Step Result: (array([-2.6076470e-02, -2.0818603e-01,  1.7018568e-04,  2.9522514e-01],
#       dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.03024019, -0.0130665 ,  0.00607469,  0.0025959 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.03050152,  0.18196781,  0.00612661, -0.28816423], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.02686216, -0.01324098,  0.00036332,  0.00644467], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.02712698,  0.18187577,  0.00049222, -0.2861236 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.02348947, -0.0132532 , -0.00523026,  0.00671453], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.02375453,  0.18194336, -0.00509597, -0.28761402], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.02011566, -0.01310555, -0.01084825,  0.00345735], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.02037778, -0.20807025, -0.0107791 ,  0.29269788], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.02453918, -0.40303686, -0.00492514,  0.5819618 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.03259992, -0.59808946,  0.00671409,  0.8730892 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.04456171, -0.40305945,  0.02417588,  0.5825247 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.0526229 , -0.20828441,  0.03582637,  0.29755452], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.05678859, -0.013691  ,  0.04177746,  0.0163824 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.05706241, -0.20938641,  0.04210511,  0.32194838], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.06125013, -0.40508187,  0.04854408,  0.6276067 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.06935177, -0.6008465 ,  0.06109621,  0.9351741 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.0813687, -0.796737 ,  0.0797997,  1.2464126], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.09730344, -0.9927866 ,  0.10472795,  1.5629874 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.11715917, -0.79906136,  0.1359877 ,  1.3047255 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.1331404 , -0.60590035,  0.16208221,  1.0575161 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.14525841, -0.4132534 ,  0.18323253,  0.8197769 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.15352347, -0.6103465 ,  0.19962807,  1.164037  ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.1657304 , -0.8074267 ,  0.22290881,  1.512088  ], dtype=float32), 1.0, True, False, {})
# Step Result: (array([-0.03909523, -0.24190594,  0.01998286,  0.32027534], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.04393335, -0.4373067 ,  0.02638836,  0.61919254], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.05267948, -0.6327871 ,  0.03877221,  0.9200683 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.06533522, -0.828411  ,  0.05717358,  1.2246798 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.08190344, -1.0242207 ,  0.08166718,  1.5347143 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.10238785, -1.2202258 ,  0.11236147,  1.8517256 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.12679237, -1.0265049 ,  0.14939597,  1.5959413 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.14732248, -0.83343685,  0.18131481,  1.3533244 ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.16399121, -1.030312  ,  0.2083813 ,  1.696811  ], dtype=float32), 1.0, False, False, {})
# Step Result: (array([-0.18459745, -0.8381134 ,  0.24231751,  1.4755716 ], dtype=float32), 1.0, True, False, {})
# Step Result: (array([ 0.04415413,  0.19119337,  0.03848433, -0.24658056], dtype=float32), 1.0, False, False, {})
# Step Result: (array([ 0.047978  ,  0.38574517,  0.03355272, -0.52688056], dtype=float32), 1.0, False, False, {})
# Step Result: (array([ 0.0556929 ,  0.19016756,  0.02301511, -0.22381663], dtype=float32), 1.0, False, False, {})
# Step Result: (array([ 0.05949625, -0.00527564,  0.01853878,  0.07603638], dtype=float32), 1.0, False, False, {})
# Step Result: (array([ 0.05939074, -0.20065838,  0.02005951,  0.37451023], dtype=float32), 1.0, False, False, {})
# Step Result: (array([ 0.05537757, -0.00582703,  0.02754971,  0.08821909], dtype=float32), 1.0, False, False, {})
# Step Result: (array([ 0.05526103,  0.18888941,  0.02931409, -0.19564615], dtype=float32), 1.0, False, False, {})
# Step Result: (array([ 0.